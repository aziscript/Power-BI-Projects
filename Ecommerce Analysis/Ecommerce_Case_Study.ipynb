# %% [markdown]
# ### 📦 Case Study: Ecommerce Analysis in Power BI
#
# ---
#
# #### 📝 **Description**
#
# In this Power BI case study, I analyzed sales and shipping data from **Whiskique**, a real-world ecommerce business specializing in pet supplies. The objective was to uncover sales performance insights, understand customer distribution, and build an executive dashboard to support decision-making across marketing, operations, and finance departments.
#
# Using **Power Query**, I cleaned and prepared the data. With **DAX**, I built calculated measures to drive visualizations. The final result is an interactive, multi-page dashboard that highlights key business metrics and simulates the impact of different shipping scenarios.
#
# ---
#
# ### 🧠 Key Business Questions & Insights
#
# ---
#
# **Q1. What is the total number of rows in the Sales table?**
# **Answer:** 25,065 product-level records. Each row represents a sale. However, the number of invoice numbers is lower, indicating possible data issues.
#
# ---
#
# **Q2. How many customers are based in California (CA)?**
# **Answer:** 598 customers. After cleaning, 661 null invoice records (due to platform bugs) were removed to improve accuracy.
#
# ---
#
# **Q3. What's the average Customer LTV in Nevada?**
# **Answer:** $972.97. One of the highest LTVs across states — useful insight for marketing campaigns.
#
# ---
#
# **Q4. Which product has the lowest average quantity sold?**
# **Answer:** Indoor Pet Camera (Wi-Fi) at 1.25 units. Duplicate product names may be skewing this value.
#
# ---
#
# **Q5. What percentage of total sales involve shipping a single item?**
# **Answer:** 5.98%. Most sales involve multiple items per invoice — a sign of effective bundling.
#
# ---
#
# **Q6. What product is most often purchased with the Pet Hair Remover?**
# **Answer:** Earth Rated Dog Poop Bags (578 instances). A strong candidate for cross-promotion.
#
# ---
#
# **Q7. Which Central region state has the most customers?**
# **Answer:** Texas
#
# ---
#
# **Q8. Which East Coast state has the highest sales?**
# **Answer:** Florida
#
# ---
#
# ### 📈 What-If Shipping Analysis
#
# Due to the lack of automated shipping cost capture, I created a DAX-powered what-if analysis tool to test cost-saving scenarios.
#
# ---
#
# **Q9. What is the value of Shipping (Baseline)?**
# **Answer:** $385,150
#
# ---
#
# **Q10. What is the value of Shipping (What-if) for quantity = 5?**
# **Answer:** $326,055
#
# ---
#
# **Q11. What are the shipping cost savings for Dog and Puppy Pads (What-if Qty = 10)?**
# **Answer:** $10,904
#
# ---
#
# **Q12. What are the savings for Pet Odor Eliminator if shipped in quantities of 7 (vs 4.5)?**
# **Answer:** $4,184 in savings — a significant cut in cost for operations and finance.
#
# ---
#
# ### 💰 Profitability Metrics
#
# ---
#
# **Q13. What is Whiskique’s overall profit percentage?**
# **Answer:** 27.50%
#
# ---
#
# **Q14. What is the profit percentage for NextGard Chew in Washington (WA)?**
# **Answer:** -19.76%
#
# ---
#
# **Q15. Which category has the highest profit margin?**
# **Answer:** Electronics (44.28%). However, only two products exist in this category — a potential expansion opportunity.
#
# ---
#
# **Q16. What product would you recommend for a cross-sell promotion with the highest selling product?**
# **Answer:** Memory Foam Pet Beds for Small, Medium, and Large Dogs and Cats — most frequently purchased with the top-selling dog food.
#
# ---
#
# ### 🛒 Product Insights
#
# ---
#
# **Q17. What is the average product quantity for "Pet Food"?**
# **Answer:** 5.31 — the highest among all categories.
#
# ---
#
# **Q18. What is the difference in average quantity sold: Electronics vs Disposables?**
# **Answer:** 1.96
# - Electronics: 1.38
# - Disposables: 3.34
# Marketing chose disposables for the “Buy 2, Get 15% Off” promotion.
#
# ---
#
# **Q19. What is the sales amount for the second-best seller (Memory Foam Pet Bed)?**
# **Answer:** $127.64K
#
# ---
#
# **Q20. What is the shipping cost savings if average quantity shipped = 11?**
# **Answer:** $118,190.40
#
# ---
#
# ### 🧩 Final Notes
#
# - **Memory Foam Pet Bed** in the **Disposables** category is the second-best seller.
# - Frequently bought with the **Taste of the Wild High Prairie Grain-Free Dog Food (40lb)** — ideal for a cross-sell campaign.
# - The dashboard offers a centralized view of Whiskique’s KPIs and lets stakeholders run what-if shipping simulations, enabling better decisions across marketing, ops, and finance.
